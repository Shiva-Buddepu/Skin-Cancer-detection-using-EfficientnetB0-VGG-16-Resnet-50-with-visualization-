# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("/content/train-metadata.csv",on_bad_lines='skip')
# Out:
# <ipython-input-2-1d1e48157a51>:6: DtypeWarning: Columns (52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/train-metadata.csv",on_bad_lines='skip')

# %%
# Set the style for seaborn
sns.set_style("whitegrid")

# 1. Age Distribution
plt.figure(figsize=(8,5))
sns.histplot(df["age_approx"].dropna(), bins=10, kde=True, color='blue')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
# 2. Sex Distribution
plt.figure(figsize=(6,4))
sns.countplot(x=df["sex"], palette="coolwarm")
plt.title("Sex Distribution")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-5-2742d0ff660d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["sex"], palette="coolwarm")

# %%
# 3. Lesion Location Distribution
plt.figure(figsize=(10,5))
sns.countplot(y=df["anatom_site_general"], order=df["anatom_site_general"].value_counts().index, palette="viridis")
plt.title("Lesion Location Distribution")
plt.xlabel("Count")
plt.ylabel("Anatomical Site")
plt.show()
# Out:
# <ipython-input-6-ff1eb2e3fefd>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df["anatom_site_general"], order=df["anatom_site_general"].value_counts().index, palette="viridis")

# %%
# 4. Correlation Heatmap (for numerical values)
numeric_df = df.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(12,8))
sns.heatmap(numeric_df.corr(), cmap="coolwarm", annot=False)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# 5. Tumor Size Distribution
plt.figure(figsize=(8,5))
sns.histplot(df["clin_size_long_diam_mm"].dropna(), bins=10, kde=True, color='green')
plt.title("Tumor Size Distribution")
plt.xlabel("Tumor Size (mm)")
plt.ylabel("Count")
plt.show()
